# %% [markdown]
# In this lab we will explore applying the reflection pattern and how it can improve an agentic workflow that converts natural language questions to database queries written in SQL

# %%
import json
import sys
import os
import utils

import pandas as pd
from dotenv import load_dotenv
_ = load_dotenv()  # take environment variables from .env file

# %% [markdown]
# For this lab we will make use of a package called aisuite, this makes it easy to call LLMs hosted by different model providers.

# %%
import aisuite as ai

client = ai.Client()

# %% [markdown]
# In this step we will create a local SQLite database called products.db. The database will be automatically filledwith randomly generated product data

# %%
# Setup SQLite database
import utils
utils.create_Transactions_db()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Setup SQLite database
#       2 import utils
# ----> 3 utils.create_Transactions_db()
#
# AttributeError: module 'utils' has no attribute 'create_Transactions_db'
